# %%
import os, shutil
import tensorflow as tf

# %%
original_dataset_dir = '/floyd/input/skin_disease_dataset/train'

# %%
os.listdir('/floyd/input/skin_disease_dataset/train')
# Out:
# ['Scabies Lyme Disease and other Infestations and Bites',
#  'Acne and Rosacea Photos',
#  'Urticaria Hives',
#  'Cellulitis Impetigo and other Bacterial Infections',
#  'Psoriasis pictures Lichen Planus and related diseases',
#  'Tinea Ringworm Candidiasis and other Fungal Infections',
#  'Eczema Photos',
#  'Exanthems and Drug Eruptions',
#  'Light Diseases and Disorders of Pigmentation',
#  'Atopic Dermatitis Photos',
#  'Vasculitis Photos',
#  'Hair Loss Photos Alopecia and other Hair Diseases',
#  'Systemic Disease',
#  'Herpes HPV and other STDs Photos',
#  'Nail Fungus and other Nail Disease',
#  'Lupus and other Connective Tissue diseases',
#  'Melanoma Skin Cancer Nevi and Moles',
#  'Seborrheic Keratoses and other Benign Tumors',
#  'Bullous Disease Photos',
#  'Warts Molluscum and other Viral Infections',
#  'Vascular Tumors',
#  'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions',
#  'Poison Ivy Photos and other Contact Dermatitis']

# %%
import numpy as np
import pandas as pd

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

#from tensorflow.keras.applications.vgg16 import  preprocess_input
from tensorflow.keras.applications.resnet import  preprocess_input

# %%
img_width, img_height = 224, 224

# %%
def preprocess_image(path):
    img = load_img(path, target_size = (img_height, img_width))
    a = img_to_array(img)
    a = np.expand_dims(a, axis = 0)
    a = preprocess_input(a)
    return a

# %%
res = preprocess_image("/floyd/input/skin_disease_dataset/train/Acne and Rosacea Photos/07Acne081101.jpg")
print(res)
# Out:
# [[[[   8.060997     4.2210007   31.32     ]
#    [  15.060997     8.221001    36.32     ]
#    [  18.060997     9.221001    37.32     ]
#    ...
#    [   2.060997    -3.7789993   28.32     ]
#    [   5.060997    -0.7789993   31.32     ]
#    [   4.060997    -1.7789993   30.32     ]]
#
#   [[  15.060997    11.221001    38.32     ]
#    [  18.060997    11.221001    39.32     ]
#    [  20.060997    11.221001    39.32     ]
#    ...
#    [ -13.939003   -19.779       12.32     ]
#    [   9.060997     1.2210007   33.32     ]
#    [  17.060997    10.221001    40.32     ]]
#
#   [[  13.060997     9.221001    36.32     ]
#    [  13.060997     6.2210007   34.32     ]
#    [  17.060997     8.221001    36.32     ]
#    ...
#    [  19.060997    11.221001    43.32     ]
#    [  22.060997    12.221001    43.32     ]
#    [   7.060997    -2.7789993   28.32     ]]
#
#   ...
#
#   [[   7.060997     3.2210007   33.32     ]
#    [   8.060997     4.2210007   31.32     ]
#    [  21.060997    13.221001    39.32     ]
#    ...
#    [-100.939     -110.779     -113.68     ]
#    [ -99.939     -109.779     -112.68     ]
#    [ -99.939     -108.779     -114.68     ]]
#
#   [[  -0.939003    -4.7789993   25.32     ]
#    [   5.060997    -1.7789993   26.32     ]
#    [  12.060997     1.2210007   28.32     ]
#    ...
#    [ -97.939     -107.779     -110.68     ]
#    [ -99.939     -108.779     -114.68     ]
#    [ -99.939     -108.779     -114.68     ]]
#
#   [[   6.060997     1.2210007   31.32     ]
#    [   4.060997    -2.7789993   25.32     ]
#    [  17.060997     6.2210007   33.32     ]
#    ...
#    [ -99.939     -109.779     -112.68     ]
#    [ -99.939     -108.779     -114.68     ]
#    [ -99.939     -108.779     -114.68     ]]]]

# %%
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input

HEIGHT = 224
WIDTH = 224

base_model = InceptionResNetV2(weights='imagenet', 
                      include_top=False, 
                      input_shape=(HEIGHT, WIDTH, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAIN_DIR = "/floyd/input/skin_disease_dataset/train"
HEIGHT = 224
WIDTH = 224
BATCH_SIZE = 8

train_datagen =  ImageDataGenerator(
      preprocessing_function=preprocess_input,
      rotation_range=90,
      horizontal_flip=True,
      vertical_flip=True
    )

train_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                    target_size=(HEIGHT, WIDTH), 
                                                    batch_size=BATCH_SIZE)


test_datagen =  ImageDataGenerator(
      preprocessing_function=preprocess_input,
      rotation_range=90,
      horizontal_flip=True,
      vertical_flip=True
    )
validation_generator = test_datagen.flow_from_directory(
        '/floyd/input/skin_disease_dataset/test',
        target_size=(224, 224),
        batch_size=BATCH_SIZE)

val_generator = test_datagen.flow_from_directory(
        '/floyd/input/skin_disease_dataset/test',
        target_size=(224, 224),
        shuffle = False,
        batch_size=BATCH_SIZE)
# Out:
# Found 15557 images belonging to 23 classes.
# Found 4002 images belonging to 23 classes.
# Found 4002 images belonging to 23 classes.

# %%
print(validation_generator)
# Out:
# <keras_preprocessing.image.directory_iterator.DirectoryIterator object at 0x7fbcd8786650>

# %%
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout
from tensorflow.keras.models import Sequential, Model

def build_finetune_model(base_model, dropout, fc_layers, num_classes):
    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.output
    x = Flatten()(x)
    for fc in fc_layers:
        # New FC layer, random init
        x = Dense(fc, activation='relu')(x) 
        x = Dropout(dropout)(x)

    # New softmax layer
    predictions = Dense(num_classes, activation='softmax')(x) 
    
    finetune_model = Model(inputs=base_model.input, outputs=predictions)
    return finetune_model

class_list = os.listdir("/floyd/input/skin_disease_dataset/train")
FC_LAYERS = [1024, 1024]
dropout = 0.5

finetune_model = build_finetune_model(base_model, 
                                      dropout=dropout, 
                                      fc_layers=FC_LAYERS, 
                                      num_classes=len(class_list))

# %%
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

NUM_EPOCHS = 250
BATCH_SIZE = 20
num_train_images = 15557

adam = Adam(lr=0.00001)
finetune_model.compile(adam, loss='categorical_crossentropy', metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy(
    k=5, name='top_5'), tf.keras.metrics.TopKCategoricalAccuracy(
    k=3, name='top_3')])


checkpoint = ModelCheckpoint("inception-resnet.h5", monitor=["acc"], verbose=1, mode='max')
callbacks_list = [checkpoint]

history1 = finetune_model.fit(train_generator, epochs=NUM_EPOCHS, validation_data=(validation_generator),
                             workers=16, 
                             steps_per_epoch=num_train_images // BATCH_SIZE,
                             validation_steps = num_train_images // BATCH_SIZE, shuffle=True, callbacks=callbacks_list)
# Out:
# Epoch 1/250
# 777/777 [==============================] - ETA: 0s - loss: 3.3477 - accuracy: 0.1079 - top_5: 0.3425 - top_3: 0.2329
# Epoch 00001: saving model to inception-resnet.h5
# 777/777 [==============================] - 64s 83ms/step - loss: 3.3477 - accuracy: 0.1079 - top_5: 0.3425 - top_3: 0.2329 - val_loss: 2.8330 - val_accuracy: 0.1762 - val_top_5: 0.4821 - val_top_3: 0.3559
# Epoch 2/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.9587 - accuracy: 0.1456 - top_5: 0.4204 - top_3: 0.3083
# Epoch 00002: saving model to inception-resnet.h5
# 777/777 [==============================] - 63s 81ms/step - loss: 2.9585 - accuracy: 0.1454 - top_5: 0.4207 - top_3: 0.3084 - val_loss: 2.7771 - val_accuracy: 0.1863 - val_top_5: 0.5155 - val_top_3: 0.3959
# Epoch 3/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.8902 - accuracy: 0.1631 - top_5: 0.4577 - top_3: 0.3309
# Epoch 00003: saving model to inception-resnet.h5
# 777/777 [==============================] - 64s 82ms/step - loss: 2.8904 - accuracy: 0.1630 - top_5: 0.4577 - top_3: 0.3306 - val_loss: 2.7138 - val_accuracy: 0.2090 - val_top_5: 0.5554 - val_top_3: 0.4232
# Epoch 4/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.8512 - accuracy: 0.1682 - top_5: 0.4763 - top_3: 0.3516
# Epoch 00004: saving model to inception-resnet.h5
# 777/777 [==============================] - 65s 84ms/step - loss: 2.8511 - accuracy: 0.1681 - top_5: 0.4764 - top_3: 0.3517 - val_loss: 2.6791 - val_accuracy: 0.2244 - val_top_5: 0.5656 - val_top_3: 0.4370
# Epoch 5/250
# 777/777 [==============================] - ETA: 0s - loss: 2.8049 - accuracy: 0.1803 - top_5: 0.4913 - top_3: 0.3578
# Epoch 00005: saving model to inception-resnet.h5
# 777/777 [==============================] - 63s 81ms/step - loss: 2.8049 - accuracy: 0.1803 - top_5: 0.4913 - top_3: 0.3578 - val_loss: 2.6756 - val_accuracy: 0.2227 - val_top_5: 0.5622 - val_top_3: 0.4367
# Epoch 6/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.7746 - accuracy: 0.1850 - top_5: 0.5020 - top_3: 0.3823
# Epoch 00006: saving model to inception-resnet.h5
# 777/777 [==============================] - 64s 83ms/step - loss: 2.7754 - accuracy: 0.1848 - top_5: 0.5014 - top_3: 0.3818 - val_loss: 2.6359 - val_accuracy: 0.2377 - val_top_5: 0.5741 - val_top_3: 0.4428
# Epoch 7/250
# 777/777 [==============================] - ETA: 0s - loss: 2.7742 - accuracy: 0.1858 - top_5: 0.5093 - top_3: 0.3764
# Epoch 00007: saving model to inception-resnet.h5
# 777/777 [==============================] - 65s 83ms/step - loss: 2.7742 - accuracy: 0.1858 - top_5: 0.5093 - top_3: 0.3764 - val_loss: 2.6467 - val_accuracy: 0.2322 - val_top_5: 0.5770 - val_top_3: 0.4448
# Epoch 8/250
# 777/777 [==============================] - ETA: 0s - loss: 2.7270 - accuracy: 0.2025 - top_5: 0.5237 - top_3: 0.3976
# Epoch 00008: saving model to inception-resnet.h5
# 777/777 [==============================] - 65s 84ms/step - loss: 2.7270 - accuracy: 0.2025 - top_5: 0.5237 - top_3: 0.3976 - val_loss: 2.5918 - val_accuracy: 0.2465 - val_top_5: 0.5799 - val_top_3: 0.4552
# Epoch 9/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.7263 - accuracy: 0.1928 - top_5: 0.5266 - top_3: 0.4045
# Epoch 00009: saving model to inception-resnet.h5
# 777/777 [==============================] - 63s 81ms/step - loss: 2.7257 - accuracy: 0.1931 - top_5: 0.5269 - top_3: 0.4046 - val_loss: 2.5686 - val_accuracy: 0.2434 - val_top_5: 0.5927 - val_top_3: 0.4562
# Epoch 10/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.6938 - accuracy: 0.2102 - top_5: 0.5398 - top_3: 0.4043
# Epoch 00010: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.6934 - accuracy: 0.2104 - top_5: 0.5397 - top_3: 0.4043 - val_loss: 2.5768 - val_accuracy: 0.2562 - val_top_5: 0.6013 - val_top_3: 0.4715
# Epoch 11/250
# 777/777 [==============================] - ETA: 0s - loss: 2.6996 - accuracy: 0.2038 - top_5: 0.5472 - top_3: 0.4178
# Epoch 00011: saving model to inception-resnet.h5
# 777/777 [==============================] - 65s 84ms/step - loss: 2.6996 - accuracy: 0.2038 - top_5: 0.5472 - top_3: 0.4178 - val_loss: 2.5668 - val_accuracy: 0.2511 - val_top_5: 0.5880 - val_top_3: 0.4632
# Epoch 12/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.6710 - accuracy: 0.2117 - top_5: 0.5469 - top_3: 0.4283
# Epoch 00012: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.6713 - accuracy: 0.2114 - top_5: 0.5467 - top_3: 0.4282 - val_loss: 2.5728 - val_accuracy: 0.2556 - val_top_5: 0.5979 - val_top_3: 0.4712
# Epoch 13/250
# 777/777 [==============================] - ETA: 0s - loss: 2.6475 - accuracy: 0.2258 - top_5: 0.5600 - top_3: 0.4338
# Epoch 00013: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.6475 - accuracy: 0.2258 - top_5: 0.5600 - top_3: 0.4338 - val_loss: 2.5373 - val_accuracy: 0.2566 - val_top_5: 0.6138 - val_top_3: 0.4766
# Epoch 14/250
# 777/777 [==============================] - ETA: 0s - loss: 2.6545 - accuracy: 0.2215 - top_5: 0.5600 - top_3: 0.4368
# Epoch 00014: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 84ms/step - loss: 2.6545 - accuracy: 0.2215 - top_5: 0.5600 - top_3: 0.4368 - val_loss: 2.5236 - val_accuracy: 0.2596 - val_top_5: 0.6061 - val_top_3: 0.4776
# Epoch 15/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.6391 - accuracy: 0.2250 - top_5: 0.5596 - top_3: 0.4388
# Epoch 00015: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.6393 - accuracy: 0.2249 - top_5: 0.5592 - top_3: 0.4385 - val_loss: 2.5236 - val_accuracy: 0.2680 - val_top_5: 0.6114 - val_top_3: 0.4804
# Epoch 16/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.6351 - accuracy: 0.2300 - top_5: 0.5581 - top_3: 0.4414
# Epoch 00016: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.6344 - accuracy: 0.2302 - top_5: 0.5585 - top_3: 0.4417 - val_loss: 2.5066 - val_accuracy: 0.2643 - val_top_5: 0.6177 - val_top_3: 0.4845
# Epoch 17/250
# 777/777 [==============================] - ETA: 0s - loss: 2.6146 - accuracy: 0.2326 - top_5: 0.5714 - top_3: 0.4516
# Epoch 00017: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.6146 - accuracy: 0.2326 - top_5: 0.5714 - top_3: 0.4516 - val_loss: 2.5144 - val_accuracy: 0.2717 - val_top_5: 0.6138 - val_top_3: 0.4924
# Epoch 18/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5956 - accuracy: 0.2303 - top_5: 0.5839 - top_3: 0.4444
# Epoch 00018: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 87ms/step - loss: 2.5956 - accuracy: 0.2303 - top_5: 0.5839 - top_3: 0.4444 - val_loss: 2.4949 - val_accuracy: 0.2795 - val_top_5: 0.6260 - val_top_3: 0.5003
# Epoch 19/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.6072 - accuracy: 0.2316 - top_5: 0.5735 - top_3: 0.4494
# Epoch 00019: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.6076 - accuracy: 0.2318 - top_5: 0.5735 - top_3: 0.4495 - val_loss: 2.4736 - val_accuracy: 0.2762 - val_top_5: 0.6253 - val_top_3: 0.4887
# Epoch 20/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.5782 - accuracy: 0.2365 - top_5: 0.5889 - top_3: 0.4649
# Epoch 00020: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.5791 - accuracy: 0.2365 - top_5: 0.5885 - top_3: 0.4646 - val_loss: 2.4804 - val_accuracy: 0.2832 - val_top_5: 0.6309 - val_top_3: 0.5073
# Epoch 21/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5982 - accuracy: 0.2366 - top_5: 0.5804 - top_3: 0.4542
# Epoch 00021: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.5982 - accuracy: 0.2366 - top_5: 0.5804 - top_3: 0.4542 - val_loss: 2.4743 - val_accuracy: 0.2813 - val_top_5: 0.6289 - val_top_3: 0.4997
# Epoch 22/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5582 - accuracy: 0.2519 - top_5: 0.5920 - top_3: 0.4678
# Epoch 00022: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.5582 - accuracy: 0.2519 - top_5: 0.5920 - top_3: 0.4678 - val_loss: 2.4626 - val_accuracy: 0.2799 - val_top_5: 0.6240 - val_top_3: 0.4987
# Epoch 23/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.5708 - accuracy: 0.2417 - top_5: 0.5934 - top_3: 0.4670
# Epoch 00023: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.5708 - accuracy: 0.2416 - top_5: 0.5933 - top_3: 0.4669 - val_loss: 2.4400 - val_accuracy: 0.2903 - val_top_5: 0.6365 - val_top_3: 0.5126
# Epoch 24/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.5517 - accuracy: 0.2447 - top_5: 0.5934 - top_3: 0.4636
# Epoch 00024: saving model to inception-resnet.h5
# 777/777 [==============================] - 65s 84ms/step - loss: 2.5523 - accuracy: 0.2447 - top_5: 0.5933 - top_3: 0.4636 - val_loss: 2.4164 - val_accuracy: 0.2931 - val_top_5: 0.6401 - val_top_3: 0.5118
# Epoch 25/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5120 - accuracy: 0.2588 - top_5: 0.5975 - top_3: 0.4727
# Epoch 00025: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.5120 - accuracy: 0.2588 - top_5: 0.5975 - top_3: 0.4727 - val_loss: 2.4366 - val_accuracy: 0.2877 - val_top_5: 0.6301 - val_top_3: 0.5031
# Epoch 26/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.5368 - accuracy: 0.2566 - top_5: 0.5948 - top_3: 0.4749
# Epoch 00026: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.5361 - accuracy: 0.2567 - top_5: 0.5949 - top_3: 0.4748 - val_loss: 2.4110 - val_accuracy: 0.2950 - val_top_5: 0.6407 - val_top_3: 0.5142
# Epoch 27/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4993 - accuracy: 0.2650 - top_5: 0.6068 - top_3: 0.4839
# Epoch 00027: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.4993 - accuracy: 0.2650 - top_5: 0.6068 - top_3: 0.4839 - val_loss: 2.4182 - val_accuracy: 0.2964 - val_top_5: 0.6426 - val_top_3: 0.5145
# Epoch 28/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5249 - accuracy: 0.2525 - top_5: 0.6057 - top_3: 0.4769
# Epoch 00028: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.5249 - accuracy: 0.2525 - top_5: 0.6057 - top_3: 0.4769 - val_loss: 2.4174 - val_accuracy: 0.2926 - val_top_5: 0.6354 - val_top_3: 0.5084
# Epoch 29/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5021 - accuracy: 0.2685 - top_5: 0.6091 - top_3: 0.4892
# Epoch 00029: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.5021 - accuracy: 0.2685 - top_5: 0.6091 - top_3: 0.4892 - val_loss: 2.4071 - val_accuracy: 0.2992 - val_top_5: 0.6459 - val_top_3: 0.5214
# Epoch 30/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5247 - accuracy: 0.2561 - top_5: 0.5952 - top_3: 0.4735
# Epoch 00030: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.5247 - accuracy: 0.2561 - top_5: 0.5952 - top_3: 0.4735 - val_loss: 2.3947 - val_accuracy: 0.3048 - val_top_5: 0.6510 - val_top_3: 0.5293
# Epoch 31/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.5066 - accuracy: 0.2666 - top_5: 0.6021 - top_3: 0.4844
# Epoch 00031: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 87ms/step - loss: 2.5064 - accuracy: 0.2664 - top_5: 0.6023 - top_3: 0.4846 - val_loss: 2.3945 - val_accuracy: 0.2958 - val_top_5: 0.6473 - val_top_3: 0.5240
# Epoch 32/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5085 - accuracy: 0.2616 - top_5: 0.6075 - top_3: 0.4854
# Epoch 00032: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.5085 - accuracy: 0.2616 - top_5: 0.6075 - top_3: 0.4854 - val_loss: 2.3789 - val_accuracy: 0.3051 - val_top_5: 0.6510 - val_top_3: 0.5263
# Epoch 33/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.4766 - accuracy: 0.2682 - top_5: 0.6155 - top_3: 0.4977
# Epoch 00033: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.4768 - accuracy: 0.2681 - top_5: 0.6155 - top_3: 0.4977 - val_loss: 2.3855 - val_accuracy: 0.3034 - val_top_5: 0.6514 - val_top_3: 0.5224
# Epoch 34/250
# 777/777 [==============================] - ETA: 0s - loss: 2.5026 - accuracy: 0.2571 - top_5: 0.6067 - top_3: 0.4881
# Epoch 00034: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.5026 - accuracy: 0.2571 - top_5: 0.6067 - top_3: 0.4881 - val_loss: 2.3773 - val_accuracy: 0.3153 - val_top_5: 0.6533 - val_top_3: 0.5303
# Epoch 35/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.4607 - accuracy: 0.2801 - top_5: 0.6250 - top_3: 0.5023
# Epoch 00035: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.4607 - accuracy: 0.2801 - top_5: 0.6248 - top_3: 0.5021 - val_loss: 2.4040 - val_accuracy: 0.2921 - val_top_5: 0.6397 - val_top_3: 0.5134
# Epoch 36/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4625 - accuracy: 0.2744 - top_5: 0.6229 - top_3: 0.4988
# Epoch 00036: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.4625 - accuracy: 0.2744 - top_5: 0.6229 - top_3: 0.4988 - val_loss: 2.3783 - val_accuracy: 0.3105 - val_top_5: 0.6536 - val_top_3: 0.5333
# Epoch 37/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4589 - accuracy: 0.2736 - top_5: 0.6202 - top_3: 0.5010
# Epoch 00037: saving model to inception-resnet.h5
# 777/777 [==============================] - 66s 85ms/step - loss: 2.4589 - accuracy: 0.2736 - top_5: 0.6202 - top_3: 0.5010 - val_loss: 2.3689 - val_accuracy: 0.3059 - val_top_5: 0.6481 - val_top_3: 0.5300
# Epoch 38/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4523 - accuracy: 0.2751 - top_5: 0.6200 - top_3: 0.4998
# Epoch 00038: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 87ms/step - loss: 2.4523 - accuracy: 0.2751 - top_5: 0.6200 - top_3: 0.4998 - val_loss: 2.3603 - val_accuracy: 0.3140 - val_top_5: 0.6544 - val_top_3: 0.5314
# Epoch 39/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.4524 - accuracy: 0.2780 - top_5: 0.6271 - top_3: 0.5077
# Epoch 00039: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.4519 - accuracy: 0.2783 - top_5: 0.6271 - top_3: 0.5077 - val_loss: 2.3704 - val_accuracy: 0.3088 - val_top_5: 0.6628 - val_top_3: 0.5316
# Epoch 40/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4518 - accuracy: 0.2775 - top_5: 0.6205 - top_3: 0.5026
# Epoch 00040: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.4518 - accuracy: 0.2775 - top_5: 0.6205 - top_3: 0.5026 - val_loss: 2.3584 - val_accuracy: 0.3097 - val_top_5: 0.6560 - val_top_3: 0.5362
# Epoch 41/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.4467 - accuracy: 0.2830 - top_5: 0.6282 - top_3: 0.5036
# Epoch 00041: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.4467 - accuracy: 0.2831 - top_5: 0.6285 - top_3: 0.5038 - val_loss: 2.3306 - val_accuracy: 0.3267 - val_top_5: 0.6610 - val_top_3: 0.5450
# Epoch 42/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4564 - accuracy: 0.2802 - top_5: 0.6207 - top_3: 0.5011
# Epoch 00042: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 87ms/step - loss: 2.4564 - accuracy: 0.2802 - top_5: 0.6207 - top_3: 0.5011 - val_loss: 2.3402 - val_accuracy: 0.3219 - val_top_5: 0.6539 - val_top_3: 0.5359
# Epoch 43/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4243 - accuracy: 0.2773 - top_5: 0.6309 - top_3: 0.5091
# Epoch 00043: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.4243 - accuracy: 0.2773 - top_5: 0.6309 - top_3: 0.5091 - val_loss: 2.3550 - val_accuracy: 0.3159 - val_top_5: 0.6583 - val_top_3: 0.5301
# Epoch 44/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.4086 - accuracy: 0.2896 - top_5: 0.6342 - top_3: 0.5184
# Epoch 00044: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.4086 - accuracy: 0.2894 - top_5: 0.6342 - top_3: 0.5183 - val_loss: 2.3319 - val_accuracy: 0.3237 - val_top_5: 0.6720 - val_top_3: 0.5461
# Epoch 45/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.4141 - accuracy: 0.2974 - top_5: 0.6377 - top_3: 0.5187
# Epoch 00045: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.4133 - accuracy: 0.2975 - top_5: 0.6380 - top_3: 0.5191 - val_loss: 2.3335 - val_accuracy: 0.3184 - val_top_5: 0.6601 - val_top_3: 0.5396
# Epoch 46/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4177 - accuracy: 0.2949 - top_5: 0.6343 - top_3: 0.5144
# Epoch 00046: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.4177 - accuracy: 0.2949 - top_5: 0.6343 - top_3: 0.5144 - val_loss: 2.3351 - val_accuracy: 0.3214 - val_top_5: 0.6647 - val_top_3: 0.5388
# Epoch 47/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.4079 - accuracy: 0.2969 - top_5: 0.6406 - top_3: 0.5222
# Epoch 00047: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.4087 - accuracy: 0.2967 - top_5: 0.6406 - top_3: 0.5219 - val_loss: 2.3097 - val_accuracy: 0.3262 - val_top_5: 0.6721 - val_top_3: 0.5435
# Epoch 48/250
# 777/777 [==============================] - ETA: 0s - loss: 2.4025 - accuracy: 0.2907 - top_5: 0.6353 - top_3: 0.5205
# Epoch 00048: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.4025 - accuracy: 0.2907 - top_5: 0.6353 - top_3: 0.5205 - val_loss: 2.3225 - val_accuracy: 0.3275 - val_top_5: 0.6730 - val_top_3: 0.5537
# Epoch 49/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3984 - accuracy: 0.2976 - top_5: 0.6453 - top_3: 0.5225
# Epoch 00049: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 88ms/step - loss: 2.3984 - accuracy: 0.2976 - top_5: 0.6453 - top_3: 0.5225 - val_loss: 2.3019 - val_accuracy: 0.3317 - val_top_5: 0.6718 - val_top_3: 0.5501
# Epoch 50/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.4062 - accuracy: 0.2920 - top_5: 0.6366 - top_3: 0.5164
# Epoch 00050: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.4064 - accuracy: 0.2917 - top_5: 0.6367 - top_3: 0.5166 - val_loss: 2.3248 - val_accuracy: 0.3225 - val_top_5: 0.6678 - val_top_3: 0.5417
# Epoch 51/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3683 - accuracy: 0.3033 - top_5: 0.6512 - top_3: 0.5346
# Epoch 00051: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.3671 - accuracy: 0.3036 - top_5: 0.6517 - top_3: 0.5348 - val_loss: 2.2956 - val_accuracy: 0.3258 - val_top_5: 0.6733 - val_top_3: 0.5559
# Epoch 52/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3812 - accuracy: 0.2999 - top_5: 0.6438 - top_3: 0.5217
# Epoch 00052: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 89ms/step - loss: 2.3798 - accuracy: 0.3004 - top_5: 0.6441 - top_3: 0.5222 - val_loss: 2.3081 - val_accuracy: 0.3322 - val_top_5: 0.6805 - val_top_3: 0.5467
# Epoch 53/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3725 - accuracy: 0.2957 - top_5: 0.6396 - top_3: 0.5210
# Epoch 00053: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.3725 - accuracy: 0.2957 - top_5: 0.6396 - top_3: 0.5210 - val_loss: 2.3112 - val_accuracy: 0.3328 - val_top_5: 0.6707 - val_top_3: 0.5501
# Epoch 54/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3716 - accuracy: 0.2947 - top_5: 0.6461 - top_3: 0.5243
# Epoch 00054: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 88ms/step - loss: 2.3716 - accuracy: 0.2947 - top_5: 0.6461 - top_3: 0.5243 - val_loss: 2.3022 - val_accuracy: 0.3322 - val_top_5: 0.6792 - val_top_3: 0.5559
# Epoch 55/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3528 - accuracy: 0.3077 - top_5: 0.6485 - top_3: 0.5303
# Epoch 00055: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 88ms/step - loss: 2.3541 - accuracy: 0.3073 - top_5: 0.6483 - top_3: 0.5298 - val_loss: 2.2867 - val_accuracy: 0.3369 - val_top_5: 0.6692 - val_top_3: 0.5525
# Epoch 56/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3638 - accuracy: 0.3070 - top_5: 0.6451 - top_3: 0.5222
# Epoch 00056: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 90ms/step - loss: 2.3649 - accuracy: 0.3066 - top_5: 0.6449 - top_3: 0.5218 - val_loss: 2.2726 - val_accuracy: 0.3378 - val_top_5: 0.6796 - val_top_3: 0.5592
# Epoch 57/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3716 - accuracy: 0.3068 - top_5: 0.6472 - top_3: 0.5238
# Epoch 00057: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 89ms/step - loss: 2.3716 - accuracy: 0.3068 - top_5: 0.6472 - top_3: 0.5238 - val_loss: 2.2963 - val_accuracy: 0.3312 - val_top_5: 0.6738 - val_top_3: 0.5507
# Epoch 58/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3688 - accuracy: 0.3060 - top_5: 0.6538 - top_3: 0.5280
# Epoch 00058: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 90ms/step - loss: 2.3685 - accuracy: 0.3061 - top_5: 0.6540 - top_3: 0.5282 - val_loss: 2.2891 - val_accuracy: 0.3362 - val_top_5: 0.6799 - val_top_3: 0.5496
# Epoch 59/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3512 - accuracy: 0.3034 - top_5: 0.6631 - top_3: 0.5375
# Epoch 00059: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 90ms/step - loss: 2.3512 - accuracy: 0.3034 - top_5: 0.6631 - top_3: 0.5375 - val_loss: 2.2982 - val_accuracy: 0.3332 - val_top_5: 0.6742 - val_top_3: 0.5552
# Epoch 60/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3564 - accuracy: 0.3106 - top_5: 0.6480 - top_3: 0.5301
# Epoch 00060: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.3562 - accuracy: 0.3108 - top_5: 0.6480 - top_3: 0.5302 - val_loss: 2.2691 - val_accuracy: 0.3351 - val_top_5: 0.6802 - val_top_3: 0.5627
# Epoch 61/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3534 - accuracy: 0.3095 - top_5: 0.6522 - top_3: 0.5323
# Epoch 00061: saving model to inception-resnet.h5
# 777/777 [==============================] - 72s 93ms/step - loss: 2.3534 - accuracy: 0.3095 - top_5: 0.6522 - top_3: 0.5323 - val_loss: 2.2930 - val_accuracy: 0.3329 - val_top_5: 0.6799 - val_top_3: 0.5591
# Epoch 62/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3479 - accuracy: 0.3082 - top_5: 0.6606 - top_3: 0.5337
# Epoch 00062: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 90ms/step - loss: 2.3475 - accuracy: 0.3082 - top_5: 0.6606 - top_3: 0.5338 - val_loss: 2.2646 - val_accuracy: 0.3356 - val_top_5: 0.6778 - val_top_3: 0.5503
# Epoch 63/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3326 - accuracy: 0.3106 - top_5: 0.6572 - top_3: 0.5373
# Epoch 00063: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 89ms/step - loss: 2.3326 - accuracy: 0.3105 - top_5: 0.6572 - top_3: 0.5373 - val_loss: 2.2724 - val_accuracy: 0.3358 - val_top_5: 0.6794 - val_top_3: 0.5554
# Epoch 64/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3565 - accuracy: 0.3058 - top_5: 0.6467 - top_3: 0.5312
# Epoch 00064: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 89ms/step - loss: 2.3565 - accuracy: 0.3058 - top_5: 0.6467 - top_3: 0.5312 - val_loss: 2.2574 - val_accuracy: 0.3465 - val_top_5: 0.6841 - val_top_3: 0.5699
# Epoch 65/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3242 - accuracy: 0.3138 - top_5: 0.6624 - top_3: 0.5401
# Epoch 00065: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 91ms/step - loss: 2.3251 - accuracy: 0.3135 - top_5: 0.6622 - top_3: 0.5397 - val_loss: 2.2666 - val_accuracy: 0.3327 - val_top_5: 0.6921 - val_top_3: 0.5664
# Epoch 66/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3036 - accuracy: 0.3188 - top_5: 0.6689 - top_3: 0.5472
# Epoch 00066: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 88ms/step - loss: 2.3036 - accuracy: 0.3188 - top_5: 0.6689 - top_3: 0.5472 - val_loss: 2.2509 - val_accuracy: 0.3419 - val_top_5: 0.6837 - val_top_3: 0.5665
# Epoch 67/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3174 - accuracy: 0.3196 - top_5: 0.6659 - top_3: 0.5482
# Epoch 00067: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.3178 - accuracy: 0.3197 - top_5: 0.6660 - top_3: 0.5481 - val_loss: 2.2381 - val_accuracy: 0.3409 - val_top_5: 0.6929 - val_top_3: 0.5751
# Epoch 68/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3636 - accuracy: 0.3012 - top_5: 0.6537 - top_3: 0.5270
# Epoch 00068: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.3640 - accuracy: 0.3010 - top_5: 0.6538 - top_3: 0.5268 - val_loss: 2.2758 - val_accuracy: 0.3345 - val_top_5: 0.6821 - val_top_3: 0.5596
# Epoch 69/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3099 - accuracy: 0.3174 - top_5: 0.6636 - top_3: 0.5439
# Epoch 00069: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.3099 - accuracy: 0.3174 - top_5: 0.6636 - top_3: 0.5439 - val_loss: 2.2580 - val_accuracy: 0.3404 - val_top_5: 0.6933 - val_top_3: 0.5751
# Epoch 70/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2962 - accuracy: 0.3241 - top_5: 0.6687 - top_3: 0.5488
# Epoch 00070: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.2962 - accuracy: 0.3238 - top_5: 0.6684 - top_3: 0.5487 - val_loss: 2.2744 - val_accuracy: 0.3409 - val_top_5: 0.6817 - val_top_3: 0.5596
# Epoch 71/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2889 - accuracy: 0.3280 - top_5: 0.6724 - top_3: 0.5502
# Epoch 00071: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.2892 - accuracy: 0.3279 - top_5: 0.6723 - top_3: 0.5501 - val_loss: 2.2672 - val_accuracy: 0.3390 - val_top_5: 0.6839 - val_top_3: 0.5657
# Epoch 72/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3010 - accuracy: 0.3200 - top_5: 0.6728 - top_3: 0.5542
# Epoch 00072: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 88ms/step - loss: 2.3010 - accuracy: 0.3200 - top_5: 0.6728 - top_3: 0.5542 - val_loss: 2.2282 - val_accuracy: 0.3475 - val_top_5: 0.6926 - val_top_3: 0.5693
# Epoch 73/250
# 777/777 [==============================] - ETA: 0s - loss: 2.3080 - accuracy: 0.3283 - top_5: 0.6647 - top_3: 0.5527
# Epoch 00073: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.3080 - accuracy: 0.3283 - top_5: 0.6647 - top_3: 0.5527 - val_loss: 2.2412 - val_accuracy: 0.3464 - val_top_5: 0.6881 - val_top_3: 0.5699
# Epoch 74/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3013 - accuracy: 0.3251 - top_5: 0.6638 - top_3: 0.5433
# Epoch 00074: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 87ms/step - loss: 2.3008 - accuracy: 0.3253 - top_5: 0.6639 - top_3: 0.5436 - val_loss: 2.2448 - val_accuracy: 0.3448 - val_top_5: 0.6925 - val_top_3: 0.5753
# Epoch 75/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2926 - accuracy: 0.3270 - top_5: 0.6680 - top_3: 0.5536
# Epoch 00075: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.2922 - accuracy: 0.3274 - top_5: 0.6681 - top_3: 0.5539 - val_loss: 2.2313 - val_accuracy: 0.3488 - val_top_5: 0.6934 - val_top_3: 0.5728
# Epoch 76/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2750 - accuracy: 0.3297 - top_5: 0.6748 - top_3: 0.5562
# Epoch 00076: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.2757 - accuracy: 0.3295 - top_5: 0.6744 - top_3: 0.5558 - val_loss: 2.2303 - val_accuracy: 0.3477 - val_top_5: 0.6910 - val_top_3: 0.5698
# Epoch 77/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.3032 - accuracy: 0.3194 - top_5: 0.6683 - top_3: 0.5548
# Epoch 00077: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 91ms/step - loss: 2.3035 - accuracy: 0.3193 - top_5: 0.6683 - top_3: 0.5547 - val_loss: 2.2317 - val_accuracy: 0.3474 - val_top_5: 0.6907 - val_top_3: 0.5671
# Epoch 78/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2826 - accuracy: 0.3291 - top_5: 0.6694 - top_3: 0.5497
# Epoch 00078: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.2826 - accuracy: 0.3291 - top_5: 0.6694 - top_3: 0.5497 - val_loss: 2.2405 - val_accuracy: 0.3517 - val_top_5: 0.6911 - val_top_3: 0.5725
# Epoch 79/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2684 - accuracy: 0.3311 - top_5: 0.6792 - top_3: 0.5660
# Epoch 00079: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 91ms/step - loss: 2.2684 - accuracy: 0.3311 - top_5: 0.6792 - top_3: 0.5660 - val_loss: 2.2457 - val_accuracy: 0.3440 - val_top_5: 0.6881 - val_top_3: 0.5704
# Epoch 80/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2897 - accuracy: 0.3196 - top_5: 0.6772 - top_3: 0.5627
# Epoch 00080: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 89ms/step - loss: 2.2900 - accuracy: 0.3195 - top_5: 0.6771 - top_3: 0.5626 - val_loss: 2.2349 - val_accuracy: 0.3496 - val_top_5: 0.6963 - val_top_3: 0.5779
# Epoch 81/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2682 - accuracy: 0.3272 - top_5: 0.6733 - top_3: 0.5598
# Epoch 00081: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 91ms/step - loss: 2.2682 - accuracy: 0.3272 - top_5: 0.6733 - top_3: 0.5598 - val_loss: 2.2104 - val_accuracy: 0.3475 - val_top_5: 0.6944 - val_top_3: 0.5751
# Epoch 82/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2911 - accuracy: 0.3243 - top_5: 0.6683 - top_3: 0.5565
# Epoch 00082: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 89ms/step - loss: 2.2911 - accuracy: 0.3243 - top_5: 0.6683 - top_3: 0.5565 - val_loss: 2.2283 - val_accuracy: 0.3507 - val_top_5: 0.7018 - val_top_3: 0.5813
# Epoch 83/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2553 - accuracy: 0.3356 - top_5: 0.6794 - top_3: 0.5667
# Epoch 00083: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 88ms/step - loss: 2.2553 - accuracy: 0.3356 - top_5: 0.6794 - top_3: 0.5667 - val_loss: 2.2375 - val_accuracy: 0.3448 - val_top_5: 0.6920 - val_top_3: 0.5729
# Epoch 84/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2562 - accuracy: 0.3332 - top_5: 0.6839 - top_3: 0.5677
# Epoch 00084: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 91ms/step - loss: 2.2562 - accuracy: 0.3332 - top_5: 0.6839 - top_3: 0.5677 - val_loss: 2.2161 - val_accuracy: 0.3522 - val_top_5: 0.7025 - val_top_3: 0.5779
# Epoch 85/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2782 - accuracy: 0.3286 - top_5: 0.6774 - top_3: 0.5569
# Epoch 00085: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 89ms/step - loss: 2.2774 - accuracy: 0.3288 - top_5: 0.6776 - top_3: 0.5573 - val_loss: 2.2083 - val_accuracy: 0.3549 - val_top_5: 0.7024 - val_top_3: 0.5792
# Epoch 86/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2472 - accuracy: 0.3315 - top_5: 0.6880 - top_3: 0.5695
# Epoch 00086: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 92ms/step - loss: 2.2468 - accuracy: 0.3316 - top_5: 0.6882 - top_3: 0.5698 - val_loss: 2.2006 - val_accuracy: 0.3536 - val_top_5: 0.6965 - val_top_3: 0.5762
# Epoch 87/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2585 - accuracy: 0.3297 - top_5: 0.6761 - top_3: 0.5554
# Epoch 00087: saving model to inception-resnet.h5
# 777/777 [==============================] - 67s 86ms/step - loss: 2.2587 - accuracy: 0.3300 - top_5: 0.6760 - top_3: 0.5555 - val_loss: 2.2264 - val_accuracy: 0.3443 - val_top_5: 0.6878 - val_top_3: 0.5694
# Epoch 88/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2509 - accuracy: 0.3375 - top_5: 0.6812 - top_3: 0.5651
# Epoch 00088: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 88ms/step - loss: 2.2509 - accuracy: 0.3375 - top_5: 0.6812 - top_3: 0.5651 - val_loss: 2.2046 - val_accuracy: 0.3524 - val_top_5: 0.6937 - val_top_3: 0.5796
# Epoch 89/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2238 - accuracy: 0.3319 - top_5: 0.6945 - top_3: 0.5737
# Epoch 00089: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 92ms/step - loss: 2.2238 - accuracy: 0.3319 - top_5: 0.6945 - top_3: 0.5737 - val_loss: 2.2329 - val_accuracy: 0.3483 - val_top_5: 0.6924 - val_top_3: 0.5717
# Epoch 90/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2526 - accuracy: 0.3369 - top_5: 0.6794 - top_3: 0.5676
# Epoch 00090: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.2526 - accuracy: 0.3369 - top_5: 0.6794 - top_3: 0.5676 - val_loss: 2.2044 - val_accuracy: 0.3607 - val_top_5: 0.7034 - val_top_3: 0.5851
# Epoch 91/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2198 - accuracy: 0.3359 - top_5: 0.6880 - top_3: 0.5713
# Epoch 00091: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 92ms/step - loss: 2.2201 - accuracy: 0.3357 - top_5: 0.6881 - top_3: 0.5711 - val_loss: 2.2184 - val_accuracy: 0.3470 - val_top_5: 0.6896 - val_top_3: 0.5785
# Epoch 92/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2478 - accuracy: 0.3377 - top_5: 0.6821 - top_3: 0.5653
# Epoch 00092: saving model to inception-resnet.h5
# 777/777 [==============================] - 69s 88ms/step - loss: 2.2478 - accuracy: 0.3377 - top_5: 0.6821 - top_3: 0.5653 - val_loss: 2.2202 - val_accuracy: 0.3623 - val_top_5: 0.7024 - val_top_3: 0.5815
# Epoch 93/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2195 - accuracy: 0.3473 - top_5: 0.6884 - top_3: 0.5701
# Epoch 00093: saving model to inception-resnet.h5
# 777/777 [==============================] - 73s 94ms/step - loss: 2.2195 - accuracy: 0.3473 - top_5: 0.6884 - top_3: 0.5701 - val_loss: 2.2015 - val_accuracy: 0.3609 - val_top_5: 0.7065 - val_top_3: 0.5858
# Epoch 94/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2482 - accuracy: 0.3409 - top_5: 0.6812 - top_3: 0.5652
# Epoch 00094: saving model to inception-resnet.h5
# 777/777 [==============================] - 68s 88ms/step - loss: 2.2475 - accuracy: 0.3411 - top_5: 0.6813 - top_3: 0.5655 - val_loss: 2.1949 - val_accuracy: 0.3520 - val_top_5: 0.7056 - val_top_3: 0.5831
# Epoch 95/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2169 - accuracy: 0.3409 - top_5: 0.6921 - top_3: 0.5726 ETA: 0s - loss: 2.2164 - accuracy: 0.3410 - top_5: 0.6924 - top_3
# Epoch 00095: saving model to inception-resnet.h5
# 777/777 [==============================] - 73s 93ms/step - loss: 2.2169 - accuracy: 0.3409 - top_5: 0.6921 - top_3: 0.5726 - val_loss: 2.1853 - val_accuracy: 0.3544 - val_top_5: 0.7018 - val_top_3: 0.5825
# Epoch 96/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2103 - accuracy: 0.3448 - top_5: 0.6882 - top_3: 0.5759
# Epoch 00096: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 90ms/step - loss: 2.2103 - accuracy: 0.3448 - top_5: 0.6882 - top_3: 0.5759 - val_loss: 2.1994 - val_accuracy: 0.3572 - val_top_5: 0.7064 - val_top_3: 0.5860
# Epoch 97/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2287 - accuracy: 0.3465 - top_5: 0.6896 - top_3: 0.5718
# Epoch 00097: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 90ms/step - loss: 2.2291 - accuracy: 0.3462 - top_5: 0.6894 - top_3: 0.5716 - val_loss: 2.2012 - val_accuracy: 0.3572 - val_top_5: 0.6999 - val_top_3: 0.5835
# Epoch 98/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2341 - accuracy: 0.3451 - top_5: 0.6852 - top_3: 0.5709
# Epoch 00098: saving model to inception-resnet.h5
# 777/777 [==============================] - 74s 95ms/step - loss: 2.2341 - accuracy: 0.3451 - top_5: 0.6852 - top_3: 0.5709 - val_loss: 2.1885 - val_accuracy: 0.3598 - val_top_5: 0.7060 - val_top_3: 0.5896
# Epoch 99/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2140 - accuracy: 0.3436 - top_5: 0.6951 - top_3: 0.5762
# Epoch 00099: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 92ms/step - loss: 2.2145 - accuracy: 0.3438 - top_5: 0.6951 - top_3: 0.5764 - val_loss: 2.2059 - val_accuracy: 0.3520 - val_top_5: 0.6990 - val_top_3: 0.5784
# Epoch 100/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2046 - accuracy: 0.3417 - top_5: 0.6939 - top_3: 0.5842
# Epoch 00100: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 90ms/step - loss: 2.2043 - accuracy: 0.3417 - top_5: 0.6942 - top_3: 0.5843 - val_loss: 2.1910 - val_accuracy: 0.3590 - val_top_5: 0.7091 - val_top_3: 0.5872
# Epoch 101/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2349 - accuracy: 0.3349 - top_5: 0.6795 - top_3: 0.5695
# Epoch 00101: saving model to inception-resnet.h5
# 777/777 [==============================] - 74s 95ms/step - loss: 2.2349 - accuracy: 0.3349 - top_5: 0.6795 - top_3: 0.5695 - val_loss: 2.1665 - val_accuracy: 0.3696 - val_top_5: 0.7127 - val_top_3: 0.5932
# Epoch 102/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2136 - accuracy: 0.3473 - top_5: 0.6865 - top_3: 0.5735
# Epoch 00102: saving model to inception-resnet.h5
# 777/777 [==============================] - 72s 92ms/step - loss: 2.2136 - accuracy: 0.3473 - top_5: 0.6865 - top_3: 0.5735 - val_loss: 2.2062 - val_accuracy: 0.3546 - val_top_5: 0.7066 - val_top_3: 0.5909
# Epoch 103/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2218 - accuracy: 0.3390 - top_5: 0.6911 - top_3: 0.5706
# Epoch 00103: saving model to inception-resnet.h5
# 777/777 [==============================] - 72s 93ms/step - loss: 2.2218 - accuracy: 0.3390 - top_5: 0.6911 - top_3: 0.5706 - val_loss: 2.1985 - val_accuracy: 0.3551 - val_top_5: 0.7048 - val_top_3: 0.5894
# Epoch 104/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2026 - accuracy: 0.3426 - top_5: 0.6912 - top_3: 0.5757
# Epoch 00104: saving model to inception-resnet.h5
# 777/777 [==============================] - 73s 94ms/step - loss: 2.2029 - accuracy: 0.3425 - top_5: 0.6913 - top_3: 0.5756 - val_loss: 2.2004 - val_accuracy: 0.3552 - val_top_5: 0.7050 - val_top_3: 0.5878
# Epoch 105/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1594 - accuracy: 0.3607 - top_5: 0.7047 - top_3: 0.5938
# Epoch 00105: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 90ms/step - loss: 2.1600 - accuracy: 0.3604 - top_5: 0.7048 - top_3: 0.5938 - val_loss: 2.1710 - val_accuracy: 0.3591 - val_top_5: 0.7142 - val_top_3: 0.5901
# Epoch 106/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1747 - accuracy: 0.3581 - top_5: 0.6981 - top_3: 0.5845
# Epoch 00106: saving model to inception-resnet.h5
# 777/777 [==============================] - 74s 95ms/step - loss: 2.1742 - accuracy: 0.3583 - top_5: 0.6981 - top_3: 0.5844 - val_loss: 2.1716 - val_accuracy: 0.3631 - val_top_5: 0.7079 - val_top_3: 0.5871
# Epoch 107/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1985 - accuracy: 0.3493 - top_5: 0.6971 - top_3: 0.5833
# Epoch 00107: saving model to inception-resnet.h5
# 777/777 [==============================] - 72s 93ms/step - loss: 2.1985 - accuracy: 0.3493 - top_5: 0.6971 - top_3: 0.5833 - val_loss: 2.1906 - val_accuracy: 0.3606 - val_top_5: 0.6970 - val_top_3: 0.5841
# Epoch 108/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1627 - accuracy: 0.3573 - top_5: 0.6985 - top_3: 0.5912
# Epoch 00108: saving model to inception-resnet.h5
# 777/777 [==============================] - 74s 95ms/step - loss: 2.1627 - accuracy: 0.3573 - top_5: 0.6985 - top_3: 0.5912 - val_loss: 2.1492 - val_accuracy: 0.3702 - val_top_5: 0.7206 - val_top_3: 0.6055
# Epoch 109/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1976 - accuracy: 0.3466 - top_5: 0.6941 - top_3: 0.5712
# Epoch 00109: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 91ms/step - loss: 2.1980 - accuracy: 0.3467 - top_5: 0.6942 - top_3: 0.5714 - val_loss: 2.1708 - val_accuracy: 0.3657 - val_top_5: 0.7083 - val_top_3: 0.5969
# Epoch 110/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.2078 - accuracy: 0.3360 - top_5: 0.6947 - top_3: 0.5726
# Epoch 00110: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 91ms/step - loss: 2.2079 - accuracy: 0.3359 - top_5: 0.6947 - top_3: 0.5727 - val_loss: 2.1800 - val_accuracy: 0.3538 - val_top_5: 0.7084 - val_top_3: 0.5897
# Epoch 111/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1895 - accuracy: 0.3554 - top_5: 0.7065 - top_3: 0.5800
# Epoch 00111: saving model to inception-resnet.h5
# 777/777 [==============================] - 73s 94ms/step - loss: 2.1894 - accuracy: 0.3555 - top_5: 0.7066 - top_3: 0.5802 - val_loss: 2.1697 - val_accuracy: 0.3725 - val_top_5: 0.7101 - val_top_3: 0.5965
# Epoch 112/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1869 - accuracy: 0.3521 - top_5: 0.6972 - top_3: 0.5851
# Epoch 00112: saving model to inception-resnet.h5
# 777/777 [==============================] - 72s 93ms/step - loss: 2.1866 - accuracy: 0.3522 - top_5: 0.6972 - top_3: 0.5853 - val_loss: 2.1644 - val_accuracy: 0.3719 - val_top_5: 0.7129 - val_top_3: 0.6017
# Epoch 113/250
# 777/777 [==============================] - ETA: 0s - loss: 2.2054 - accuracy: 0.3417 - top_5: 0.6956 - top_3: 0.5777
# Epoch 00113: saving model to inception-resnet.h5
# 777/777 [==============================] - 72s 92ms/step - loss: 2.2054 - accuracy: 0.3417 - top_5: 0.6956 - top_3: 0.5777 - val_loss: 2.1639 - val_accuracy: 0.3671 - val_top_5: 0.7137 - val_top_3: 0.5982
# Epoch 114/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1629 - accuracy: 0.3520 - top_5: 0.7114 - top_3: 0.5922 ETA: 0s - loss: 2.1604 - accuracy: 0.3526 - top_5: 0.7116 - top_3
# Epoch 00114: saving model to inception-resnet.h5
# 777/777 [==============================] - 74s 95ms/step - loss: 2.1629 - accuracy: 0.3520 - top_5: 0.7114 - top_3: 0.5922 - val_loss: 2.1747 - val_accuracy: 0.3696 - val_top_5: 0.7184 - val_top_3: 0.5967
# Epoch 115/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1823 - accuracy: 0.3512 - top_5: 0.7044 - top_3: 0.5881
# Epoch 00115: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 91ms/step - loss: 2.1816 - accuracy: 0.3514 - top_5: 0.7048 - top_3: 0.5883 - val_loss: 2.1640 - val_accuracy: 0.3726 - val_top_5: 0.7101 - val_top_3: 0.5942
# Epoch 116/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1836 - accuracy: 0.3492 - top_5: 0.7039 - top_3: 0.5879
# Epoch 00116: saving model to inception-resnet.h5
# 777/777 [==============================] - 73s 94ms/step - loss: 2.1843 - accuracy: 0.3489 - top_5: 0.7037 - top_3: 0.5875 - val_loss: 2.1626 - val_accuracy: 0.3756 - val_top_5: 0.7136 - val_top_3: 0.5938
# Epoch 117/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1852 - accuracy: 0.3571 - top_5: 0.6985 - top_3: 0.5882
# Epoch 00117: saving model to inception-resnet.h5
# 777/777 [==============================] - 74s 95ms/step - loss: 2.1852 - accuracy: 0.3571 - top_5: 0.6985 - top_3: 0.5882 - val_loss: 2.1715 - val_accuracy: 0.3611 - val_top_5: 0.7162 - val_top_3: 0.6012
# Epoch 118/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1400 - accuracy: 0.3595 - top_5: 0.7127 - top_3: 0.5963
# Epoch 00118: saving model to inception-resnet.h5
# 777/777 [==============================] - 71s 91ms/step - loss: 2.1400 - accuracy: 0.3594 - top_5: 0.7124 - top_3: 0.5962 - val_loss: 2.1380 - val_accuracy: 0.3723 - val_top_5: 0.7177 - val_top_3: 0.6010
# Epoch 119/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1480 - accuracy: 0.3670 - top_5: 0.7101 - top_3: 0.5977
# Epoch 00119: saving model to inception-resnet.h5
# 777/777 [==============================] - 74s 96ms/step - loss: 2.1480 - accuracy: 0.3670 - top_5: 0.7101 - top_3: 0.5977 - val_loss: 2.1423 - val_accuracy: 0.3643 - val_top_5: 0.7116 - val_top_3: 0.5930
# Epoch 120/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1563 - accuracy: 0.3587 - top_5: 0.7068 - top_3: 0.5909
# Epoch 00120: saving model to inception-resnet.h5
# 777/777 [==============================] - 70s 91ms/step - loss: 2.1545 - accuracy: 0.3589 - top_5: 0.7072 - top_3: 0.5914 - val_loss: 2.1515 - val_accuracy: 0.3712 - val_top_5: 0.7101 - val_top_3: 0.5973
# Epoch 121/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1582 - accuracy: 0.3617 - top_5: 0.7035 - top_3: 0.5909
# Epoch 00121: saving model to inception-resnet.h5
# 777/777 [==============================] - 72s 92ms/step - loss: 2.1582 - accuracy: 0.3617 - top_5: 0.7035 - top_3: 0.5909 - val_loss: 2.1584 - val_accuracy: 0.3662 - val_top_5: 0.7099 - val_top_3: 0.5946
# Epoch 122/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1909 - accuracy: 0.3522 - top_5: 0.6971 - top_3: 0.5861
# Epoch 00122: saving model to inception-resnet.h5
# 777/777 [==============================] - 76s 97ms/step - loss: 2.1909 - accuracy: 0.3522 - top_5: 0.6971 - top_3: 0.5861 - val_loss: 2.1556 - val_accuracy: 0.3694 - val_top_5: 0.7087 - val_top_3: 0.5897
# Epoch 123/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1410 - accuracy: 0.3584 - top_5: 0.7092 - top_3: 0.6020
# Epoch 00123: saving model to inception-resnet.h5
# 777/777 [==============================] - 72s 92ms/step - loss: 2.1410 - accuracy: 0.3584 - top_5: 0.7092 - top_3: 0.6020 - val_loss: 2.1505 - val_accuracy: 0.3691 - val_top_5: 0.7171 - val_top_3: 0.6017
# Epoch 124/250
# 777/777 [==============================] - ETA: 0s - loss: 2.1510 - accuracy: 0.3581 - top_5: 0.7070 - top_3: 0.5919
# Epoch 00124: saving model to inception-resnet.h5
# 777/777 [==============================] - 75s 96ms/step - loss: 2.1510 - accuracy: 0.3581 - top_5: 0.7070 - top_3: 0.5919 - val_loss: 2.1555 - val_accuracy: 0.3693 - val_top_5: 0.7168 - val_top_3: 0.5938
# Epoch 125/250
# 776/777 [============================>.] - ETA: 0s - loss: 2.1340 - accuracy: 0.3742 - top_5: 0.7146 - top_3: 0.5984
# Epoch 00125: saving model to inception-resnet.h5
# ...
# 777/777 [==============================] - 82s 105ms/step - loss: 1.9729 - accuracy: 0.4141 - top_5: 0.7519 - top_3: 0.6474 - val_loss: 2.0443 - val_accuracy: 0.3991 - val_top_5: 0.7426 - val_top_3: 0.6302
# Epoch 211/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9802 - accuracy: 0.4038 - top_5: 0.7510 - top_3: 0.6425
# Epoch 00211: saving model to inception-resnet.h5
# 777/777 [==============================] - 86s 111ms/step - loss: 1.9802 - accuracy: 0.4038 - top_5: 0.7510 - top_3: 0.6425 - val_loss: 2.0318 - val_accuracy: 0.3961 - val_top_5: 0.7385 - val_top_3: 0.6301
# Epoch 212/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9639 - accuracy: 0.4125 - top_5: 0.7510 - top_3: 0.6437
# Epoch 00212: saving model to inception-resnet.h5
# 777/777 [==============================] - 85s 110ms/step - loss: 1.9636 - accuracy: 0.4126 - top_5: 0.7511 - top_3: 0.6438 - val_loss: 2.0611 - val_accuracy: 0.3907 - val_top_5: 0.7419 - val_top_3: 0.6248
# Epoch 213/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9757 - accuracy: 0.4046 - top_5: 0.7484 - top_3: 0.6449
# Epoch 00213: saving model to inception-resnet.h5
# 777/777 [==============================] - 85s 110ms/step - loss: 1.9757 - accuracy: 0.4046 - top_5: 0.7484 - top_3: 0.6449 - val_loss: 2.0471 - val_accuracy: 0.3965 - val_top_5: 0.7425 - val_top_3: 0.6264
# Epoch 214/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9350 - accuracy: 0.4189 - top_5: 0.7600 - top_3: 0.6557
# Epoch 00214: saving model to inception-resnet.h5
# 777/777 [==============================] - 85s 109ms/step - loss: 1.9350 - accuracy: 0.4189 - top_5: 0.7600 - top_3: 0.6557 - val_loss: 2.0576 - val_accuracy: 0.3992 - val_top_5: 0.7382 - val_top_3: 0.6306
# Epoch 215/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9764 - accuracy: 0.4133 - top_5: 0.7514 - top_3: 0.6409
# Epoch 00215: saving model to inception-resnet.h5
# 777/777 [==============================] - 84s 108ms/step - loss: 1.9767 - accuracy: 0.4130 - top_5: 0.7514 - top_3: 0.6409 - val_loss: 2.0307 - val_accuracy: 0.4064 - val_top_5: 0.7423 - val_top_3: 0.6380
# Epoch 216/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9339 - accuracy: 0.4197 - top_5: 0.7542 - top_3: 0.6572 ETA: 0s - loss: 1.9399 - accuracy: 0.4187 - top_5
# Epoch 00216: saving model to inception-resnet.h5
# 777/777 [==============================] - 86s 110ms/step - loss: 1.9343 - accuracy: 0.4196 - top_5: 0.7542 - top_3: 0.6572 - val_loss: 2.0573 - val_accuracy: 0.3952 - val_top_5: 0.7403 - val_top_3: 0.6296
# Epoch 217/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9599 - accuracy: 0.4130 - top_5: 0.7543 - top_3: 0.6506
# Epoch 00217: saving model to inception-resnet.h5
# 777/777 [==============================] - 83s 106ms/step - loss: 1.9599 - accuracy: 0.4130 - top_5: 0.7543 - top_3: 0.6506 - val_loss: 2.0337 - val_accuracy: 0.4160 - val_top_5: 0.7477 - val_top_3: 0.6438
# Epoch 218/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9601 - accuracy: 0.4120 - top_5: 0.7502 - top_3: 0.6511
# Epoch 00218: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 111ms/step - loss: 1.9601 - accuracy: 0.4120 - top_5: 0.7502 - top_3: 0.6511 - val_loss: 2.0419 - val_accuracy: 0.3961 - val_top_5: 0.7401 - val_top_3: 0.6295
# Epoch 219/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9423 - accuracy: 0.4199 - top_5: 0.7566 - top_3: 0.6496
# Epoch 00219: saving model to inception-resnet.h5
# 777/777 [==============================] - 86s 111ms/step - loss: 1.9423 - accuracy: 0.4199 - top_5: 0.7566 - top_3: 0.6496 - val_loss: 2.0498 - val_accuracy: 0.3959 - val_top_5: 0.7424 - val_top_3: 0.6325
# Epoch 220/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9898 - accuracy: 0.4035 - top_5: 0.7442 - top_3: 0.6371
# Epoch 00220: saving model to inception-resnet.h5
# 777/777 [==============================] - 86s 111ms/step - loss: 1.9898 - accuracy: 0.4035 - top_5: 0.7442 - top_3: 0.6371 - val_loss: 2.0432 - val_accuracy: 0.4025 - val_top_5: 0.7398 - val_top_3: 0.6317
# Epoch 221/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9588 - accuracy: 0.4072 - top_5: 0.7565 - top_3: 0.6480
# Epoch 00221: saving model to inception-resnet.h5
# 777/777 [==============================] - 84s 108ms/step - loss: 1.9588 - accuracy: 0.4072 - top_5: 0.7565 - top_3: 0.6480 - val_loss: 2.0432 - val_accuracy: 0.3942 - val_top_5: 0.7407 - val_top_3: 0.6319
# Epoch 222/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9602 - accuracy: 0.4186 - top_5: 0.7551 - top_3: 0.6462
# Epoch 00222: saving model to inception-resnet.h5
# 777/777 [==============================] - 86s 111ms/step - loss: 1.9602 - accuracy: 0.4186 - top_5: 0.7551 - top_3: 0.6462 - val_loss: 2.0298 - val_accuracy: 0.4014 - val_top_5: 0.7469 - val_top_3: 0.6289
# Epoch 223/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9322 - accuracy: 0.4250 - top_5: 0.7583 - top_3: 0.6603 ETA: 1s - loss: 1.9262 - accuracy
# Epoch 00223: saving model to inception-resnet.h5
# 777/777 [==============================] - 86s 110ms/step - loss: 1.9325 - accuracy: 0.4249 - top_5: 0.7578 - top_3: 0.6599 - val_loss: 2.0269 - val_accuracy: 0.4056 - val_top_5: 0.7481 - val_top_3: 0.6353
# Epoch 224/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9395 - accuracy: 0.4140 - top_5: 0.7629 - top_3: 0.6543 ETA: 1s - loss: 1.9326 - ac
# Epoch 00224: saving model to inception-resnet.h5
# 777/777 [==============================] - 83s 107ms/step - loss: 1.9391 - accuracy: 0.4139 - top_5: 0.7630 - top_3: 0.6544 - val_loss: 2.0367 - val_accuracy: 0.3964 - val_top_5: 0.7403 - val_top_3: 0.6315
# Epoch 225/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9737 - accuracy: 0.4136 - top_5: 0.7476 - top_3: 0.6517
# Epoch 00225: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 111ms/step - loss: 1.9737 - accuracy: 0.4136 - top_5: 0.7476 - top_3: 0.6517 - val_loss: 2.0392 - val_accuracy: 0.4068 - val_top_5: 0.7446 - val_top_3: 0.6372
# Epoch 226/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9449 - accuracy: 0.4140 - top_5: 0.7616 - top_3: 0.6569
# Epoch 00226: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 112ms/step - loss: 1.9446 - accuracy: 0.4141 - top_5: 0.7616 - top_3: 0.6570 - val_loss: 2.0371 - val_accuracy: 0.4010 - val_top_5: 0.7503 - val_top_3: 0.6364
# Epoch 227/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9646 - accuracy: 0.4059 - top_5: 0.7523 - top_3: 0.6478
# Epoch 00227: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 112ms/step - loss: 1.9646 - accuracy: 0.4059 - top_5: 0.7523 - top_3: 0.6478 - val_loss: 2.0432 - val_accuracy: 0.3991 - val_top_5: 0.7405 - val_top_3: 0.6289
# Epoch 228/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9334 - accuracy: 0.4201 - top_5: 0.7591 - top_3: 0.6559 ETA: 1s - loss: 1.932
# Epoch 00228: saving model to inception-resnet.h5
# 777/777 [==============================] - 86s 111ms/step - loss: 1.9334 - accuracy: 0.4201 - top_5: 0.7591 - top_3: 0.6559 - val_loss: 2.0293 - val_accuracy: 0.4077 - val_top_5: 0.7477 - val_top_3: 0.6306
# Epoch 229/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9501 - accuracy: 0.4149 - top_5: 0.7553 - top_3: 0.6477 ETA: 3s - loss: 1.9595 - accuracy: 0.4121 - - ETA: 2s - loss:
# Epoch 00229: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 112ms/step - loss: 1.9501 - accuracy: 0.4149 - top_5: 0.7553 - top_3: 0.6477 - val_loss: 2.0286 - val_accuracy: 0.3964 - val_top_5: 0.7510 - val_top_3: 0.6365
# Epoch 230/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9610 - accuracy: 0.4091 - top_5: 0.7592 - top_3: 0.6503
# Epoch 00230: saving model to inception-resnet.h5
# 777/777 [==============================] - 86s 111ms/step - loss: 1.9599 - accuracy: 0.4094 - top_5: 0.7593 - top_3: 0.6506 - val_loss: 2.0374 - val_accuracy: 0.4061 - val_top_5: 0.7457 - val_top_3: 0.6333
# Epoch 231/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9534 - accuracy: 0.4156 - top_5: 0.7631 - top_3: 0.6474
# Epoch 00231: saving model to inception-resnet.h5
# 777/777 [==============================] - 84s 108ms/step - loss: 1.9535 - accuracy: 0.4157 - top_5: 0.7631 - top_3: 0.6475 - val_loss: 2.0449 - val_accuracy: 0.3902 - val_top_5: 0.7437 - val_top_3: 0.6291
# Epoch 232/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9277 - accuracy: 0.4181 - top_5: 0.7608 - top_3: 0.6557
# Epoch 00232: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 113ms/step - loss: 1.9277 - accuracy: 0.4181 - top_5: 0.7608 - top_3: 0.6557 - val_loss: 2.0178 - val_accuracy: 0.4034 - val_top_5: 0.7507 - val_top_3: 0.6390
# Epoch 233/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9528 - accuracy: 0.4140 - top_5: 0.7507 - top_3: 0.6485
# Epoch 00233: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 112ms/step - loss: 1.9526 - accuracy: 0.4136 - top_5: 0.7508 - top_3: 0.6483 - val_loss: 2.0210 - val_accuracy: 0.4017 - val_top_5: 0.7465 - val_top_3: 0.6349
# Epoch 234/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9311 - accuracy: 0.4212 - top_5: 0.7606 - top_3: 0.6569
# Epoch 00234: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 112ms/step - loss: 1.9311 - accuracy: 0.4212 - top_5: 0.7606 - top_3: 0.6569 - val_loss: 2.0187 - val_accuracy: 0.4055 - val_top_5: 0.7481 - val_top_3: 0.6446
# Epoch 235/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9361 - accuracy: 0.4270 - top_5: 0.7695 - top_3: 0.6597
# Epoch 00235: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 112ms/step - loss: 1.9361 - accuracy: 0.4270 - top_5: 0.7695 - top_3: 0.6597 - val_loss: 2.0197 - val_accuracy: 0.4118 - val_top_5: 0.7473 - val_top_3: 0.6322
# Epoch 236/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9414 - accuracy: 0.4169 - top_5: 0.7605 - top_3: 0.6530 ETA: 1s - loss:
# Epoch 00236: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 112ms/step - loss: 1.9414 - accuracy: 0.4169 - top_5: 0.7605 - top_3: 0.6530 - val_loss: 2.0328 - val_accuracy: 0.3978 - val_top_5: 0.7495 - val_top_3: 0.6378
# Epoch 237/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9281 - accuracy: 0.4181 - top_5: 0.7598 - top_3: 0.6544
# Epoch 00237: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 112ms/step - loss: 1.9281 - accuracy: 0.4181 - top_5: 0.7598 - top_3: 0.6544 - val_loss: 2.0337 - val_accuracy: 0.4005 - val_top_5: 0.7446 - val_top_3: 0.6348
# Epoch 238/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9426 - accuracy: 0.4190 - top_5: 0.7594 - top_3: 0.6507
# Epoch 00238: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 114ms/step - loss: 1.9426 - accuracy: 0.4190 - top_5: 0.7594 - top_3: 0.6507 - val_loss: 2.0153 - val_accuracy: 0.4030 - val_top_5: 0.7506 - val_top_3: 0.6368
# Epoch 239/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9128 - accuracy: 0.4268 - top_5: 0.7651 - top_3: 0.6569
# Epoch 00239: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 113ms/step - loss: 1.9128 - accuracy: 0.4268 - top_5: 0.7651 - top_3: 0.6569 - val_loss: 2.0294 - val_accuracy: 0.4040 - val_top_5: 0.7475 - val_top_3: 0.6345
# Epoch 240/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9212 - accuracy: 0.4191 - top_5: 0.7606 - top_3: 0.6551
# Epoch 00240: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 113ms/step - loss: 1.9206 - accuracy: 0.4194 - top_5: 0.7608 - top_3: 0.6551 - val_loss: 2.0417 - val_accuracy: 0.4005 - val_top_5: 0.7506 - val_top_3: 0.6335
# Epoch 241/250
# 777/777 [==============================] - ETA: 0s - loss: 1.8829 - accuracy: 0.4328 - top_5: 0.7768 - top_3: 0.6741
# Epoch 00241: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 113ms/step - loss: 1.8829 - accuracy: 0.4328 - top_5: 0.7768 - top_3: 0.6741 - val_loss: 2.0060 - val_accuracy: 0.4151 - val_top_5: 0.7524 - val_top_3: 0.6410
# Epoch 242/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9332 - accuracy: 0.4237 - top_5: 0.7635 - top_3: 0.6596
# Epoch 00242: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 114ms/step - loss: 1.9332 - accuracy: 0.4237 - top_5: 0.7635 - top_3: 0.6596 - val_loss: 2.0132 - val_accuracy: 0.4021 - val_top_5: 0.7491 - val_top_3: 0.6375
# Epoch 243/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9375 - accuracy: 0.4136 - top_5: 0.7655 - top_3: 0.6549
# Epoch 00243: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 113ms/step - loss: 1.9375 - accuracy: 0.4136 - top_5: 0.7655 - top_3: 0.6549 - val_loss: 2.0396 - val_accuracy: 0.4010 - val_top_5: 0.7436 - val_top_3: 0.6365
# Epoch 244/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9126 - accuracy: 0.4245 - top_5: 0.7647 - top_3: 0.6667
# Epoch 00244: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 113ms/step - loss: 1.9123 - accuracy: 0.4245 - top_5: 0.7645 - top_3: 0.6667 - val_loss: 2.0206 - val_accuracy: 0.3990 - val_top_5: 0.7467 - val_top_3: 0.6361
# Epoch 245/250
# 777/777 [==============================] - ETA: 0s - loss: 1.8965 - accuracy: 0.4289 - top_5: 0.7683 - top_3: 0.6639
# Epoch 00245: saving model to inception-resnet.h5
# 777/777 [==============================] - 84s 108ms/step - loss: 1.8965 - accuracy: 0.4289 - top_5: 0.7683 - top_3: 0.6639 - val_loss: 2.0092 - val_accuracy: 0.4110 - val_top_5: 0.7476 - val_top_3: 0.6407
# Epoch 246/250
# 777/777 [==============================] - ETA: 0s - loss: 1.8862 - accuracy: 0.4352 - top_5: 0.7676 - top_3: 0.6626
# Epoch 00246: saving model to inception-resnet.h5
# 777/777 [==============================] - 89s 114ms/step - loss: 1.8862 - accuracy: 0.4352 - top_5: 0.7676 - top_3: 0.6626 - val_loss: 2.0094 - val_accuracy: 0.4034 - val_top_5: 0.7565 - val_top_3: 0.6412
# Epoch 247/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9190 - accuracy: 0.4162 - top_5: 0.7616 - top_3: 0.6556
# Epoch 00247: saving model to inception-resnet.h5
# 777/777 [==============================] - 89s 114ms/step - loss: 1.9190 - accuracy: 0.4162 - top_5: 0.7616 - top_3: 0.6556 - val_loss: 2.0144 - val_accuracy: 0.4139 - val_top_5: 0.7500 - val_top_3: 0.6420
# Epoch 248/250
# 776/777 [============================>.] - ETA: 0s - loss: 1.9224 - accuracy: 0.4255 - top_5: 0.7615 - top_3: 0.6556 ETA: 0s - loss: 1.9212 - accuracy: 0.4256 - top_5: 0.
# Epoch 00248: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 113ms/step - loss: 1.9218 - accuracy: 0.4259 - top_5: 0.7615 - top_3: 0.6557 - val_loss: 2.0234 - val_accuracy: 0.3988 - val_top_5: 0.7497 - val_top_3: 0.6364
# Epoch 249/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9079 - accuracy: 0.4260 - top_5: 0.7661 - top_3: 0.6625
# Epoch 00249: saving model to inception-resnet.h5
# 777/777 [==============================] - 88s 113ms/step - loss: 1.9079 - accuracy: 0.4260 - top_5: 0.7661 - top_3: 0.6625 - val_loss: 2.0116 - val_accuracy: 0.4068 - val_top_5: 0.7504 - val_top_3: 0.6396
# Epoch 250/250
# 777/777 [==============================] - ETA: 0s - loss: 1.9005 - accuracy: 0.4220 - top_5: 0.7708 - top_3: 0.6673 ETA: 0s - loss: 1.8999 - accuracy: 0.4232 - top_5:
# Epoch 00250: saving model to inception-resnet.h5
# 777/777 [==============================] - 87s 113ms/step - loss: 1.9005 - accuracy: 0.4220 - top_5: 0.7708 - top_3: 0.6673 - val_loss: 1.9939 - val_accuracy: 0.4136 - val_top_5: 0.7503 - val_top_3: 0.6462

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history1.history['accuracy'])
    plt.plot(history1.history['val_accuracy'])
except KeyError:
    plt.plot(history1.history['acc'])
    plt.plot(history1.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
inceptionres = tf.keras.models.load_model('inception-resnet.h5')

# %%
Y_pred = inceptionres.predict(val_generator, verbose = 1)

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
target_names = ['Urticaria Hives', 'Seborrheic Keratoses and other Benign Tumors', 'Poison Ivy Photos and other Contact Dermatitis', 'Acne and Rosacea Photos', 'Vascular Tumors', 'Eczema Photos', 'Psoriasis pictures Lichen Planus and related diseases', 'Exanthems and Drug Eruptions', 'Lupus and other Connective Tissue diseases', 'Scabies Lyme Disease and other Infestations and Bites', 'Bullous Disease Photos', 'Nail Fungus and other Nail Disease', 'Tinea Ringworm Candidiasis and other Fungal Infections', 'Systemic Disease', 'Light Diseases and Disorders of Pigmentation', 'Atopic Dermatitis Photos', 'Warts Molluscum and other Viral Infections', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Melanoma Skin Cancer Nevi and Moles', 'Vasculitis Photos', 'Cellulitis Impetigo and other Bacterial Infections', 'Hair Loss Photos Alopecia and other Hair Diseases', 'Herpes HPV and other STDs Photos']
matrix = confusion_matrix(validation_generator.classes, y_pred)
print(confusion_matrix(validation_generator.classes, y_pred))
print('InceptionResNet - V2 Classification Report')
target_names = ['Urticaria Hives', 'Seborrheic Keratoses and other Benign Tumors', 'Poison Ivy Photos and other Contact Dermatitis', 'Acne and Rosacea Photos', 'Vascular Tumors', 'Eczema Photos', 'Psoriasis pictures Lichen Planus and related diseases', 'Exanthems and Drug Eruptions', 'Lupus and other Connective Tissue diseases', 'Scabies Lyme Disease and other Infestations and Bites', 'Bullous Disease Photos', 'Nail Fungus and other Nail Disease', 'Tinea Ringworm Candidiasis and other Fungal Infections', 'Systemic Disease', 'Light Diseases and Disorders of Pigmentation', 'Atopic Dermatitis Photos', 'Warts Molluscum and other Viral Infections', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Melanoma Skin Cancer Nevi and Moles', 'Vasculitis Photos', 'Cellulitis Impetigo and other Bacterial Infections', 'Hair Loss Photos Alopecia and other Hair Diseases', 'Herpes HPV and other STDs Photos']
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
p = sns.heatmap(pd.DataFrame(matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.title('Confusion Matrix', y=1.1)

plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
fig = plt.figure(figsize=(8, 6), dpi=100)
ax = fig.add_subplot(111)
cax = ax.matshow(matrix)
fig.colorbar(cax)
plt.title('InceptionResNet-V2 Confusion matrix')

# %% [markdown]
# <h3> Not </h3>

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = finetune_model.predict_generator(validation_generator, num_train_images // 31)

# %%
print(train_generator)

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
target_names = ['Urticaria Hives', 'Seborrheic Keratoses and other Benign Tumors', 'Poison Ivy Photos and other Contact Dermatitis', 'Acne and Rosacea Photos', 'Vascular Tumors', 'Eczema Photos', 'Psoriasis pictures Lichen Planus and related diseases', 'Exanthems and Drug Eruptions', 'Lupus and other Connective Tissue diseases', 'Scabies Lyme Disease and other Infestations and Bites', 'Bullous Disease Photos', 'Nail Fungus and other Nail Disease', 'Tinea Ringworm Candidiasis and other Fungal Infections', 'Systemic Disease', 'Light Diseases and Disorders of Pigmentation', 'Atopic Dermatitis Photos', 'Warts Molluscum and other Viral Infections', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Melanoma Skin Cancer Nevi and Moles', 'Vasculitis Photos', 'Cellulitis Impetigo and other Bacterial Infections', 'Hair Loss Photos Alopecia and other Hair Diseases', 'Herpes HPV and other STDs Photos']
matrix = confusion_matrix(validation_generator.classes, y_pred)
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = ['Urticaria Hives', 'Seborrheic Keratoses and other Benign Tumors', 'Poison Ivy Photos and other Contact Dermatitis', 'Acne and Rosacea Photos', 'Vascular Tumors', 'Eczema Photos', 'Psoriasis pictures Lichen Planus and related diseases', 'Exanthems and Drug Eruptions', 'Lupus and other Connective Tissue diseases', 'Scabies Lyme Disease and other Infestations and Bites', 'Bullous Disease Photos', 'Nail Fungus and other Nail Disease', 'Tinea Ringworm Candidiasis and other Fungal Infections', 'Systemic Disease', 'Light Diseases and Disorders of Pigmentation', 'Atopic Dermatitis Photos', 'Warts Molluscum and other Viral Infections', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Melanoma Skin Cancer Nevi and Moles', 'Vasculitis Photos', 'Cellulitis Impetigo and other Bacterial Infections', 'Hair Loss Photos Alopecia and other Hair Diseases', 'Herpes HPV and other STDs Photos']
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# %%
import seaborn as sns 
p = sns.heatmap(pd.DataFrame(matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.title('Confusion Matrix', y=1.1)

plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
fig = plt.figure(figsize=(8, 6), dpi=100)
ax = fig.add_subplot(111)
cax = ax.matshow(matrix)
fig.colorbar(cax)
plt.title('Confusion matrix of the classifier')
